# %% [markdown]
# ### The distance from Lagos to other cities in Nigeria
#
# - Data - worldcities data (Basic) https://simplemaps.com/data/world-cities
# - Using: `Geopy` to calculate the geodesic distance between coordinates. https://geopy.readthedocs.io/en/stable/#module-geopy.distance and
# - `Pandas` to work with the data

# %%
import os
import pandas as pd
from geopy import distance

# %%
# data directory

input_dir = 'data'
input_filename = 'worldcities.csv'
input_path = os.path.join(input_dir, input_filename)

# %%
# Read the data (explore its structure)

input_df = pd.read_csv(input_path)
input_df
# Out:
#                    city        city_ascii      lat       lng  \
# 0                 Tokyo             Tokyo  35.6870  139.7495
# 1               Jakarta           Jakarta  -6.1750  106.8275
# 2                 Delhi             Delhi  28.6100   77.2300
# 3             Guangzhou         Guangzhou  23.1300  113.2600
# 4                Mumbai            Mumbai  19.0761   72.8775
# ...                 ...               ...      ...       ...
# 48054          Al Jabīn          Al Jabin  14.7040   43.5990
# 48055         Nelspruit         Nelspruit -25.4745   30.9703
# 48056          Gqeberha          Gqeberha -33.9681   25.5981
# 48057            Lupane            Lupane -18.9315   27.8070
# 48058  Charlotte Amalie  Charlotte Amalie  18.3420  -64.9331
#
#                    country iso2 iso3          admin_name  capital  population  \
# 0                    Japan   JP  JPN               Tōkyō  primary  37785000.0
# 1                Indonesia   ID  IDN             Jakarta  primary  33756000.0
# 2                    India   IN  IND               Delhi    admin  32226000.0
# 3                    China   CN  CHN           Guangdong    admin  26940000.0
# 4                    India   IN  IND         Mahārāshtra    admin  24973000.0
# ...                    ...  ...  ...                 ...      ...         ...
# 48054                Yemen   YE  YEM              Raymah    admin         NaN
# 48055         South Africa   ZA  ZAF          Mpumalanga    admin         NaN
# 48056         South Africa   ZA  ZAF        Eastern Cape      NaN         NaN
# 48057             Zimbabwe   ZW  ZWE  Matabeleland North    admin         NaN
# 48058  U.S. Virgin Islands   VI  VIR      Virgin Islands  primary         NaN
#
#                id
# 0      1392685764
# 1      1360771077
# 2      1356872604
# 3      1156237133
# 4      1356226629
# ...           ...
# 48054  1887910100
# 48055  1710114438
# 48056  1710000082
# 48057  1716206606
# 48058  1850037473
#
# [48059 rows x 11 columns]

# %% [markdown]
# - ##### Task: find the distance from Lagos (a city in Nigeria) to other cities in Nigeria
# - ##### Steps:
# 1. Find the coordinates of Lagos
# 2. Find the coordinates of the other cities and
# 3. Calculate the distance between Lagos and the cities
# 4. Write the result to a file/print the result

# %%
country = 'Nigeria'
city = 'Lagos'

# %%
# data on Nigeria alone
nigeria = input_df[input_df['country'] == country].copy()
nigeria
# Out:
#             city city_ascii      lat      lng  country iso2 iso3  \
# 20         Lagos      Lagos   6.4550   3.3841  Nigeria   NG  NGA
# 168         Kano       Kano  12.0000   8.5167  Nigeria   NG  NGA
# 196        Abuja      Abuja   9.0667   7.4833  Nigeria   NG  NGA
# 216       Ibadan     Ibadan   7.3964   3.9167  Nigeria   NG  NGA
# 384         Awka       Awka   6.2069   7.0678  Nigeria   NG  NGA
# ...          ...        ...      ...      ...      ...  ...  ...
# 43560       Orlu       Orlu   5.7837   7.0333  Nigeria   NG  NGA
# 47929  Abakaliki  Abakaliki   6.3249   8.1137  Nigeria   NG  NGA
# 47930    Yenagoa    Yenagoa   4.9267   6.2676  Nigeria   NG  NGA
# 47931      Gombe      Gombe  10.2904  11.1700  Nigeria   NG  NGA
# 47932  Isemi-Ile  Isemi-Ile   7.9700   3.5900  Nigeria   NG  NGA
#
#                       admin_name  capital  population          id
# 20                         Lagos    minor  16637000.0  1566593751
# 168                         Kano    admin   4224966.0  1566422868
# 196    Federal Capital Territory  primary   3770000.0  1566342270
# 216                          Oyo    admin   3552000.0  1566366407
# 384                      Anambra    admin   2171900.0  1566560581
# ...                          ...      ...         ...         ...
# 43560                        Imo    minor      9351.0  1566062510
# 47929                     Ebonyi    admin         NaN  1566879878
# 47930                    Bayelsa    admin         NaN  1566468984
# 47931                      Gombe    admin         NaN  1566855445
# 47932                        Oyo      NaN         NaN  1566369938
#
# [134 rows x 11 columns]

# %%
lagos = nigeria[nigeria['city_ascii'] == city]
lagos
# Out:
#      city city_ascii    lat     lng  country iso2 iso3 admin_name capital  \
# 20  Lagos      Lagos  6.455  3.3841  Nigeria   NG  NGA      Lagos   minor
#
#     population          id
# 20  16637000.0  1566593751

# %%
# coordinates of Lagos
city_coordinates = lagos.iloc[0]['lat'], nigeria.iloc[0]['lng']
print(city_coordinates)
# Out:
# (6.455, 3.3841)

# %%
# the coordinates of the other cities and their distance
def calculate_coordinates_distance(row):
    other_cities_coordinates = row['lat'], row['lng']
    return distance.geodesic(city_coordinates, other_cities_coordinates).km

result = nigeria.apply(calculate_coordinates_distance, axis = 1)
result
# Out:
# 20         0.000000
# 168      833.050098
# 196      536.513245
# 216      119.595830
# 384      408.504658
#             ...
# 43560    410.689939
# 47929    523.443284
# 47930    361.365643
# 47931    956.559116
# 47932    169.082752
# Length: 134, dtype: float64

# %%
# add the result to a new column

nigeria['distance_from_lagos (km)'] = result
nigeria
# Out:
#             city city_ascii      lat      lng  country iso2 iso3  \
# 20         Lagos      Lagos   6.4550   3.3841  Nigeria   NG  NGA
# 168         Kano       Kano  12.0000   8.5167  Nigeria   NG  NGA
# 196        Abuja      Abuja   9.0667   7.4833  Nigeria   NG  NGA
# 216       Ibadan     Ibadan   7.3964   3.9167  Nigeria   NG  NGA
# 384         Awka       Awka   6.2069   7.0678  Nigeria   NG  NGA
# ...          ...        ...      ...      ...      ...  ...  ...
# 43560       Orlu       Orlu   5.7837   7.0333  Nigeria   NG  NGA
# 47929  Abakaliki  Abakaliki   6.3249   8.1137  Nigeria   NG  NGA
# 47930    Yenagoa    Yenagoa   4.9267   6.2676  Nigeria   NG  NGA
# 47931      Gombe      Gombe  10.2904  11.1700  Nigeria   NG  NGA
# 47932  Isemi-Ile  Isemi-Ile   7.9700   3.5900  Nigeria   NG  NGA
#
#                       admin_name  capital  population          id  \
# 20                         Lagos    minor  16637000.0  1566593751
# 168                         Kano    admin   4224966.0  1566422868
# 196    Federal Capital Territory  primary   3770000.0  1566342270
# 216                          Oyo    admin   3552000.0  1566366407
# 384                      Anambra    admin   2171900.0  1566560581
# ...                          ...      ...         ...         ...
# 43560                        Imo    minor      9351.0  1566062510
# 47929                     Ebonyi    admin         NaN  1566879878
# 47930                    Bayelsa    admin         NaN  1566468984
# 47931                      Gombe    admin         NaN  1566855445
# 47932                        Oyo      NaN         NaN  1566369938
#
#        distance_from_lagos (km)
# 20                     0.000000
# 168                  833.050098
# 196                  536.513245
# 216                  119.595830
# 384                  408.504658
# ...                         ...
# 43560                410.689939
# 47929                523.443284
# 47930                361.365643
# 47931                956.559116
# 47932                169.082752
#
# [134 rows x 12 columns]

# %%
#excludes ths starting point (Lagos)
without_lagos = nigeria[nigeria['city_ascii'] != city].copy()
without_lagos
# Out:
#                 city     city_ascii      lat      lng  country iso2 iso3  \
# 168             Kano           Kano  12.0000   8.5167  Nigeria   NG  NGA
# 196            Abuja          Abuja   9.0667   7.4833  Nigeria   NG  NGA
# 216           Ibadan         Ibadan   7.3964   3.9167  Nigeria   NG  NGA
# 384             Awka           Awka   6.2069   7.0678  Nigeria   NG  NGA
# 433    Port Harcourt  Port Harcourt   4.8242   7.0336  Nigeria   NG  NGA
# ...              ...            ...      ...      ...      ...  ...  ...
# 43560           Orlu           Orlu   5.7837   7.0333  Nigeria   NG  NGA
# 47929      Abakaliki      Abakaliki   6.3249   8.1137  Nigeria   NG  NGA
# 47930        Yenagoa        Yenagoa   4.9267   6.2676  Nigeria   NG  NGA
# 47931          Gombe          Gombe  10.2904  11.1700  Nigeria   NG  NGA
# 47932      Isemi-Ile      Isemi-Ile   7.9700   3.5900  Nigeria   NG  NGA
#
#                       admin_name  capital  population          id  \
# 168                         Kano    admin   4224966.0  1566422868
# 196    Federal Capital Territory  primary   3770000.0  1566342270
# 216                          Oyo    admin   3552000.0  1566366407
# 384                      Anambra    admin   2171900.0  1566560581
# 433                       Rivers    admin   1865000.0  1566070649
# ...                          ...      ...         ...         ...
# 43560                        Imo    minor      9351.0  1566062510
# 47929                     Ebonyi    admin         NaN  1566879878
# 47930                    Bayelsa    admin         NaN  1566468984
# 47931                      Gombe    admin         NaN  1566855445
# 47932                        Oyo      NaN         NaN  1566369938
#
#        distance_from_lagos (km)
# 168                  833.050098
# 196                  536.513245
# 216                  119.595830
# 384                  408.504658
# 433                  442.691454
# ...                         ...
# 43560                410.689939
# 47929                523.443284
# 47930                361.365643
# 47931                956.559116
# 47932                169.082752
#
# [133 rows x 12 columns]

# %%
#cities, their state and their distance only
cities_distance_from_lagos = without_lagos[['city_ascii', 'admin_name', 'distance_from_lagos (km)']]
cities_distance_from_lagos
# Out:
#           city_ascii                 admin_name  distance_from_lagos (km)
# 168             Kano                       Kano                833.050098
# 196            Abuja  Federal Capital Territory                536.513245
# 216           Ibadan                        Oyo                119.595830
# 384             Awka                    Anambra                408.504658
# 433    Port Harcourt                     Rivers                442.691454
# ...              ...                        ...                       ...
# 43560           Orlu                        Imo                410.689939
# 47929      Abakaliki                     Ebonyi                523.443284
# 47930        Yenagoa                    Bayelsa                361.365643
# 47931          Gombe                      Gombe                956.559116
# 47932      Isemi-Ile                        Oyo                169.082752
#
# [133 rows x 3 columns]

# %%
#rename 'city_ascii' to 'city' and 'admin_name' to 'state' for clarity
cities_distance_from_lagos = cities_distance_from_lagos.rename(columns = {'city_ascii' : 'city', 'admin_name' : 'state'})
cities_distance_from_lagos
# Out:
#                 city                      state  distance_from_lagos (km)
# 168             Kano                       Kano                833.050098
# 196            Abuja  Federal Capital Territory                536.513245
# 216           Ibadan                        Oyo                119.595830
# 384             Awka                    Anambra                408.504658
# 433    Port Harcourt                     Rivers                442.691454
# ...              ...                        ...                       ...
# 43560           Orlu                        Imo                410.689939
# 47929      Abakaliki                     Ebonyi                523.443284
# 47930        Yenagoa                    Bayelsa                361.365643
# 47931          Gombe                      Gombe                956.559116
# 47932      Isemi-Ile                        Oyo                169.082752
#
# [133 rows x 3 columns]

# %%
# sorted in from nearest to farthest city from Lagos

sorted_cities_distance_from_lagos = cities_distance_from_lagos.sort_values(by = 'distance_from_lagos (km)')
sorted_cities_distance_from_lagos
# Out:
#            city    state  distance_from_lagos (km)
# 3045      Apapa    Lagos                  2.002620
# 797      Mushin    Lagos                  9.444898
# 1227     Somolu    Lagos                  9.494687
# 872       Ikeja    Lagos                 16.472919
# 1070      Agege    Lagos                 19.551129
# ...         ...      ...                       ...
# 4849       Mubi  Adamawa               1167.068663
# 625   Maiduguri    Borno               1227.426348
# 1811      Gwoza    Borno               1244.045903
# 5236       Bama    Borno               1263.144573
# 3220     Kukawa    Borno               1325.903340
#
# [133 rows x 3 columns]

# %%
# output directory

output_dir = 'result'
output_filename = 'cities_distance_from_lagos.csv'
output_path = os.path.join(output_dir, output_filename)

# %%
# write to file

sorted_cities_distance_from_lagos.to_csv(output_path, index = False)
